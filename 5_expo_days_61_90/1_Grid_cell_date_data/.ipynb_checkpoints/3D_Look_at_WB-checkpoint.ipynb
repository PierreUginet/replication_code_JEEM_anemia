# %%
list.of.packages <- c("tidyverse","data.table","stargazer","patchwork")
new.packages <- list.of.packages[!(list.of.packages %in% installed.packages()[,"Package"])]
if(length(new.packages)) install.packages(new.packages, repos = "http://cran.us.r-project.org")

invisible(lapply(list.of.packages, library, character.only = TRUE))

options(repr.matrix.max.rows=500, repr.matrix.max.cols=1200, message=FALSE, warning=TRUE)
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.0     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.2     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.1
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attachement du package : ‘data.table’
#
#
# Les objets suivants sont masqués depuis ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
#
# Les objets suivants sont masqués depuis ‘package:dplyr’:
#
#     between, first, last
#
#
# L'objet suivant est masqué depuis ‘package:purrr’:
#
#     transpose
#
#
#
# Please cite as:
#
#
#  Hlavac, Marek (2022). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.3. https://CRAN.R-project.org/package=stargazer

# %% [markdown]
# ## Dataframe

# %%
df_Ti30 <- read_csv("./output/df_WB_cells_CDC_61_90.csv")
sprintf("%i x %i dataframe", nrow(df_Ti30), ncol(df_Ti30))
head(df_Ti30,2)
# Out:
# Rows: 126725 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): WB_i61_90_bin
# dbl (4): Measured_date_CDC, cell_x, cell_y, WB_i61_90
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# [1] "126725 x 5 dataframe"
#   Measured_date_CDC cell_x cell_y WB_i61_90 WB_i61_90_bin
# 1 42489             92.50  27.5    1.719444 <=14°C
# 2 42474             91.75  27.5   -1.438889 <=14°C

# %%
as.Date(43828, origin = "1900-01-01")
# Out:
# [1] "2019-12-31"

# %%
df_Ti30_ok <- df_Ti30%>%
                filter(!is.na(WB_i61_90) & Measured_date_CDC <= 43828)%>%
                mutate(WB_i61_90_bin=factor(WB_i61_90_bin,levels=c("<=14°C","(14,16]","(16,18]","(18,20]","(20,22]","(22,24]","(24,26]","(26,28]",">28°C")))
sprintf("%i x %i dataframe", nrow(df_Ti30_ok), ncol(df_Ti30_ok))
head(df_Ti30_ok,2)
# Out:
# [1] "94089 x 5 dataframe"
#   Measured_date_CDC cell_x cell_y WB_i61_90 WB_i61_90_bin
# 1 42489             92.50  27.5    1.719444 <=14°C
# 2 42474             91.75  27.5   -1.438889 <=14°C

# %% [markdown]
# ## Calculate deciles

# %%
deciles <- quantile(df_Ti30_ok$WB_i61_90, probs = seq(0, 1, by = 0.1))
deciles
# Out:
#        0%       10%       20%       30%       40%       50%       60%       70%
# -16.36250  12.56250  15.31250  17.78750  19.91667  22.07778  23.57639  24.88056
#       80%       90%      100%
#  26.07361  27.17778  30.09306

# %% [markdown]
# ## Plot histogram per 1°C

# %%
theme_perso <- function(...) {
                    theme_bw()+
                    theme(legend.position="none",
                          plot.title = element_text(size=30),
                          axis.title.x = element_text(size = 22, face ="bold"),
                          axis.text.x =  element_text(size = 20, angle=45, hjust=1),
                          axis.title.y = element_text(size = 22, face ="bold"),
                          axis.text.y =  element_text(size = 20)
                         )
}

# %%
options(repr.plot.width=7, repr.plot.height=7, scipen=9999)

plot <- ggplot(df_Ti30_ok, aes(x = WB_i61_90)) +
              geom_histogram(fill = "lightblue", 
                             color = "black",
                             breaks = seq(-13, 31, by = 1)) +
              geom_vline(xintercept = deciles, color = "red", linetype = "dashed", linewidth = 0.5) +
              labs(title = "",
                     x = "\n WBGT (°C)",
                     y = "Number of grid cells \n") +
              xlim(-13, 31) +
              theme_minimal() + 
              theme_perso()
plot
# Out:
# Warning message:
# “Removed 52 rows containing non-finite outside the scale range (`stat_bin()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_vline()`).”
# plot without title

# %% [markdown]
# ## Bin plot

# %%
df_Ti30_boxplot <- df_Ti30_ok %>%
                        group_by(WB_i61_90_bin)%>%
                        summarize(value=n())
head(df_Ti30_boxplot,2)
# Out:
#   WB_i61_90_bin value
# 1 <=14°C        14365
# 2 (14,16]        6832

# %%
T_plot_mean_30 <- ggplot(df_Ti30_boxplot, aes(x=WB_i61_90_bin, y=value)) +
                geom_bar(stat="identity") +
                theme_perso() +
                ggtitle("30 days") +
                labs(y="Number of grid cells \n")+
                scale_x_discrete(name="\n WBGT bin (°C)")
T_plot_mean_30
# Out:
# plot without title
