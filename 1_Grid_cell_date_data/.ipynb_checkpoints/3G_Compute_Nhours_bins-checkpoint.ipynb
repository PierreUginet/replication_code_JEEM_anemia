# %%
list.of.packages <- c("tidyverse","data.table","stargazer")
new.packages <- list.of.packages[!(list.of.packages %in% installed.packages()[,"Package"])]
if(length(new.packages)) install.packages(new.packages, repos = "http://cran.us.r-project.org")

invisible(lapply(list.of.packages, library, character.only = TRUE))

options(repr.matrix.max.rows=500, repr.matrix.max.cols=1200, message=FALSE, warning=TRUE)
# Out:
# ── Attaching core tidyverse packages ────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.0     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.2.0
# ── Conflicts ──────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attachement du package : ‘data.table’
#
#
# Les objets suivants sont masqués depuis ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
#
# Les objets suivants sont masqués depuis ‘package:dplyr’:
#
#     between, first, last
#
#
# L'objet suivant est masqué depuis ‘package:purrr’:
#
#     transpose
#
#
#
# Please cite as:
#
#
#  Hlavac, Marek (2022). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.3. https://CRAN.R-project.org/package=stargazer

# %% [markdown]
# # Longer dataframe

# %%
df_deg <- fread("./interm/df_WB_cells_CDC_longer.csv")
sprintf("%i x %i dataframe", nrow(df_deg), ncol(df_deg))
head(df_deg,2)
# Out:
# [1] "30298932 x 7 dataframe"
#   Measured_date_CDC cell_x cell_y Temp_bin  N_hours Temp Day_Min
# 1 42474             91.75  27.50  T0DayMin1 1       0    1
# 2 42660             96.75  28.25  T0DayMin1 4       0    1

# %% [markdown]
# # Categorize T per hour into bins

# %%
data.frame(df_deg) %>% 
        select(Temp)%>%
        stargazer(nobs=TRUE, digits = 2,
                  summary.stat = c("n","mean", "sd","min","p25","median","p75","max"),
                  title = c("Summary statistics"),
                  type="text"
                     )
# Out:
# Summary statistics
# ====================================================================
# Statistic     N      Mean  St. Dev. Min Pctl(25) Median Pctl(75) Max
# --------------------------------------------------------------------
# Temp      30,298,932 19.78   7.13   -28    15      21      25    37
# --------------------------------------------------------------------

# %%
thresholds_WB <- c(-28,14,16,18,20,22,24,26,28,37)

# %%
df_deg_bins <- df_deg %>%
                  mutate(WB_bin = cut(Temp, breaks = thresholds_WB, 
                                     labels = c("WB_Bin_inf14","WB_Bin_14_16","WB_Bin_16_18",
                                                "WB_Bin_18_20","WB_Bin_20_22","WB_Bin_22_24",
                                                "WB_Bin_24_26","WB_Bin_26_28","WB_Bin_sup28"),
                                     include.lowest = TRUE))
sprintf("%i x %i dataframe", nrow(df_deg_bins), ncol(df_deg_bins))
head(df_deg_bins,2)
# Out:
# [1] "30298932 x 8 dataframe"
#   Measured_date_CDC cell_x cell_y Temp_bin  N_hours Temp Day_Min WB_bin
# 1 42474             91.75  27.50  T0DayMin1 1       0    1       WB_Bin_inf14
# 2 42660             96.75  28.25  T0DayMin1 4       0    1       WB_Bin_inf14

# %% [markdown]
# # Pivot wider

# %%
df_deg_wide <- df_deg_bins %>%
                        select(Measured_date_CDC,cell_x,cell_y,Day_Min,WB_bin,N_hours)%>%
                        group_by(Measured_date_CDC,cell_x,cell_y,Day_Min,WB_bin)%>%
                        summarize(N_hours=sum(N_hours))%>%
                        ungroup()%>%
                        pivot_wider(names_from = WB_bin, values_from = N_hours)%>%
                        ungroup()%>%
                        mutate_all(~replace_na(., 0))
sprintf("%i x %i dataframe", nrow(df_deg_wide), ncol(df_deg_wide))
head(df_deg_wide,2)
# Out:
# `summarise()` has grouped output by 'Measured_date_CDC', 'cell_x', 'cell_y', 'Day_Min'. You can override using the `.groups` argument.
# [1] "3801750 x 13 dataframe"
#   Measured_date_CDC cell_x cell_y Day_Min WB_Bin_18_20 WB_Bin_20_22
# 1 42022             74     15.25  1       9            5
# 2 42022             74     15.25  2       8            2
#   WB_Bin_22_24 WB_Bin_24_26 WB_Bin_16_18 WB_Bin_14_16 WB_Bin_inf14 WB_Bin_26_28
# 1 3            7            0            0            0            0
# 2 3            7            4            0            0            0
#   WB_Bin_sup28
# 1 0
# 2 0

# %%
df_deg_Nhours_30 <- df_deg_wide %>%
                        select(-Day_Min)%>%
                        group_by(Measured_date_CDC,cell_x,cell_y)%>%
                        summarise_all(list(Nhours_on30 =~ sum(.)))%>%
                        ungroup()
sprintf("%i x %i dataframe", nrow(df_deg_Nhours_30), ncol(df_deg_Nhours_30))
head(df_deg_Nhours_30,2)
# Out:
# [1] "126725 x 12 dataframe"
#   Measured_date_CDC cell_x cell_y WB_Bin_18_20_Nhours_on30
# 1 42022             74     15.25  183
# 2 42022             74     15.50  124
#   WB_Bin_20_22_Nhours_on30 WB_Bin_22_24_Nhours_on30 WB_Bin_24_26_Nhours_on30
# 1 153                      180                       91
# 2  97                      140                      107
#   WB_Bin_16_18_Nhours_on30 WB_Bin_14_16_Nhours_on30 WB_Bin_inf14_Nhours_on30
# 1  82                      25                        4
# 2 118                      79                       48
#   WB_Bin_26_28_Nhours_on30 WB_Bin_sup28_Nhours_on30
# 1 2                        0
# 2 7                        0

# %%
df_deg_Nhours_20 <- df_deg_wide %>%
                        filter(Day_Min <= 20)%>%
                        select(-Day_Min)%>%
                        group_by(Measured_date_CDC,cell_x,cell_y)%>%
                        summarise_all(list(Nhours_on20 =~ sum(.)))%>%
                        ungroup()
sprintf("%i x %i dataframe", nrow(df_deg_Nhours_20), ncol(df_deg_Nhours_20))
head(df_deg_Nhours_20,2)
# Out:
# [1] "126725 x 12 dataframe"
#   Measured_date_CDC cell_x cell_y WB_Bin_18_20_Nhours_on20
# 1 42022             74     15.25  110
# 2 42022             74     15.50   90
#   WB_Bin_20_22_Nhours_on20 WB_Bin_22_24_Nhours_on20 WB_Bin_24_26_Nhours_on20
# 1 112                      119                      55
# 2  68                       96                      68
#   WB_Bin_16_18_Nhours_on20 WB_Bin_14_16_Nhours_on20 WB_Bin_inf14_Nhours_on20
# 1 54                       25                        4
# 2 72                       41                       43
#   WB_Bin_26_28_Nhours_on20 WB_Bin_sup28_Nhours_on20
# 1 1                        0
# 2 2                        0

# %%
df_deg_Nhours_10 <- df_deg_wide %>%
                        filter(Day_Min <= 10)%>%
                        select(-Day_Min)%>%
                        group_by(Measured_date_CDC,cell_x,cell_y)%>%
                        summarise_all(list(Nhours_on10 =~ sum(.)))%>%
                        ungroup()
sprintf("%i x %i dataframe", nrow(df_deg_Nhours_10), ncol(df_deg_Nhours_10))
head(df_deg_Nhours_10,2)
# Out:
# [1] "126725 x 12 dataframe"
#   Measured_date_CDC cell_x cell_y WB_Bin_18_20_Nhours_on10
# 1 42022             74     15.25  53
# 2 42022             74     15.50  28
#   WB_Bin_20_22_Nhours_on10 WB_Bin_22_24_Nhours_on10 WB_Bin_24_26_Nhours_on10
# 1 35                       52                       24
# 2 27                       46                       24
#   WB_Bin_16_18_Nhours_on10 WB_Bin_14_16_Nhours_on10 WB_Bin_inf14_Nhours_on10
# 1 47                       25                        4
# 2 36                       36                       43
#   WB_Bin_26_28_Nhours_on10 WB_Bin_sup28_Nhours_on10
# 1 0                        0
# 2 0                        0

# %% [markdown]
# # Merge

# %%
result <- data.frame(df_deg_Nhours_30) %>%
                    left_join(df_deg_Nhours_20, by = c("Measured_date_CDC","cell_x","cell_y"))%>%
                    left_join(df_deg_Nhours_10, by = c("Measured_date_CDC","cell_x","cell_y"))
sprintf("%i x %i dataframe", nrow(result), ncol(result))
head(result,2)
# Out:
# [1] "126725 x 30 dataframe"
#   Measured_date_CDC cell_x cell_y WB_Bin_18_20_Nhours_on30
# 1 42022             74     15.25  183
# 2 42022             74     15.50  124
#   WB_Bin_20_22_Nhours_on30 WB_Bin_22_24_Nhours_on30 WB_Bin_24_26_Nhours_on30
# 1 153                      180                       91
# 2  97                      140                      107
#   WB_Bin_16_18_Nhours_on30 WB_Bin_14_16_Nhours_on30 WB_Bin_inf14_Nhours_on30
# 1  82                      25                        4
# 2 118                      79                       48
#   WB_Bin_26_28_Nhours_on30 WB_Bin_sup28_Nhours_on30 WB_Bin_18_20_Nhours_on20
# 1 2                        0                        110
# 2 7                        0                         90
#   WB_Bin_20_22_Nhours_on20 WB_Bin_22_24_Nhours_on20 WB_Bin_24_26_Nhours_on20
# 1 112                      119                      55
# 2  68                       96                      68
#   WB_Bin_16_18_Nhours_on20 WB_Bin_14_16_Nhours_on20 WB_Bin_inf14_Nhours_on20
# 1 54                       25                        4
# 2 72                       41                       43
#   WB_Bin_26_28_Nhours_on20 WB_Bin_sup28_Nhours_on20 WB_Bin_18_20_Nhours_on10
# 1 1                        0                        53
# 2 2                        0                        28
#   WB_Bin_20_22_Nhours_on10 WB_Bin_22_24_Nhours_on10 WB_Bin_24_26_Nhours_on10
# 1 35                       52                       24
# 2 27                       46                       24
#   WB_Bin_16_18_Nhours_on10 WB_Bin_14_16_Nhours_on10 WB_Bin_inf14_Nhours_on10
# 1 47                       25                        4
# 2 36                       36                       43
#   WB_Bin_26_28_Nhours_on10 WB_Bin_sup28_Nhours_on10
# 1 0                        0
# 2 0                        0

# %% [markdown]
# # Save

# %%
fwrite(result,"./output/df_WB_cells_CDC_Nhours.csv")
