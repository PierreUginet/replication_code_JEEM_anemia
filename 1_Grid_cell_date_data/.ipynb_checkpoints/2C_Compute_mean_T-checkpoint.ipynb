# %%
list.of.packages <- c("tidyverse","data.table","stargazer")
new.packages <- list.of.packages[!(list.of.packages %in% installed.packages()[,"Package"])]
if(length(new.packages)) install.packages(new.packages, repos = "http://cran.us.r-project.org")

invisible(lapply(list.of.packages, library, character.only = TRUE))

options(repr.matrix.max.rows=500, repr.matrix.max.cols=1200, message=FALSE, warning=TRUE)
# Out:
# ── Attaching core tidyverse packages ────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.0     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.2.0
# ── Conflicts ──────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attachement du package : ‘data.table’
#
#
# Les objets suivants sont masqués depuis ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
#
# Les objets suivants sont masqués depuis ‘package:dplyr’:
#
#     between, first, last
#
#
# L'objet suivant est masqué depuis ‘package:purrr’:
#
#     transpose
#
#
#
# Please cite as:
#
#
#  Hlavac, Marek (2022). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.3. https://CRAN.R-project.org/package=stargazer

# %% [markdown]
# # Longer dataframe

# %%
df_deg_bins <- fread("./interm/df_T_cells_CDC_longer.csv")
sprintf("%i x %i dataframe", nrow(df_deg_bins), ncol(df_deg_bins))
head(df_deg_bins,2)
# Out:
# [1] "53234477 x 7 dataframe"
#   Measured_date_CDC cell_x cell_y Temp_bin  N_hours Temp Day_Min
# 1 42474             91.9   27.6   T0DayMin1 2       0    1
# 2 42667             96.7   28.3   T0DayMin1 2       0    1

# %%
df_deg_bins%>%count(Day_Min)
# Out:
#    Day_Min n
# 1   1      1766072
# 2   2      1766439
# 3   3      1766947
# 4   4      1768303
# 5   5      1768954
# 6   6      1768375
# 7   7      1768557
# 8   8      1769323
# 9   9      1769276
# 10 10      1769974
# 11 11      1770402
# 12 12      1770695
# 13 13      1771889
# 14 14      1772641
# 15 15      1773175
# 16 16      1773825
# 17 17      1774831
# 18 18      1775521
# 19 19      1775387
# 20 20      1775532
# 21 21      1775940
# 22 22      1777252
# 23 23      1778228
# 24 24      1779776
# 25 25      1780695
# 26 26      1782044
# 27 27      1783708
# 28 28      1785456
# 29 29      1787234
# 30 30      1788026

# %%
df_deg_bins%>%count(N_hours)
# Out:
#    N_hours n
# 1   1      18442708
# 2   2      17775433
# 3   3       8254867
# 4   4       4304199
# 5   5       2011538
# 6   6        964596
# 7   7        531993
# 8   8        327213
# 9   9        207260
# 10 10        134754
# 11 11         89824
# 12 12         61701
# 13 13         42399
# 14 14         29073
# 15 15         17903
# 16 16         12402
# 17 17          8163
# 18 18          5810
# 19 19          3933
# 20 20          3090
# 21 21          2137
# 22 22          1322
# 23 23          1049
# 24 24          1110

# %%
df_deg_bins%>%count(Temp)
# Out:
#    Temp n
# 1  -27        8
# 2  -26       15
# 3  -25       45
# 4  -24       81
# 5  -23      105
# 6  -22      156
# 7  -21      241
# 8  -20      323
# 9  -19      477
# 10 -18      559
# 11 -17      865
# 12 -16     1153
# 13 -15     1720
# 14 -14     2265
# 15 -13     3212
# 16 -12     4327
# 17 -11     6015
# 18 -10     8106
# 19  -9    10302
# 20  -8    13645
# 21  -7    17789
# 22  -6    22558
# 23  -5    28019
# 24  -4    34276
# 25  -3    41290
# 26  -2    49332
# 27  -1    57712
# 28   0    68822
# 29   1    81823
# 30   2    97953
# 31   3   122703
# 32   4   161347
# 33   5   222424
# 34   6   307796
# 35   7   416079
# 36   8   536896
# 37   9   653798
# 38  10   773318
# 39  11   903161
# 40  12  1036430
# 41  13  1172063
# 42  14  1310341
# 43  15  1449143
# 44  16  1576587
# 45  17  1710124
# 46  18  1823594
# 47  19  1931599
# 48  20  2040370
# 49  21  2175121
# 50  22  2363448
# 51  23  2590715
# 52  24  2825284
# 53  25  3003746
# 54  26  3055837
# 55  27  2940712
# 56  28  2695970
# 57  29  2379556
# 58  30  2056080
# 59  31  1739274
# 60  32  1440541
# 61  33  1182187
# 62  34   965050
# 63  35   785135
# 64  36   645144
# 65  37   512679
# 66  38   402136
# 67  39   296308
# 68  40   211991
# 69  41   137907
# 70  42    75932
# 71  43    34132
# 72  44    14532
# 73  45     4093

# %% [markdown]
# # Computation $$T_{i}^{30}= \sum_{b} \frac{h_{ib}^{30} \times T_b}{24 \times 30}$$

# %% [markdown]
# ## 30-day exposure

# %%
result_30 <- df_deg_bins[, .(T_i30 = sum(N_hours * Temp / 24 / 30, na.rm = TRUE)), 
                          by = .(Measured_date_CDC, cell_x, cell_y)]
sprintf("%i x %i dataframe", nrow(result_30), ncol(result_30))
head(result_30,2)
# Out:
# [1] "173657 x 4 dataframe"
#   Measured_date_CDC cell_x cell_y T_i30
# 1 42474             91.9   27.6   3.495833
# 2 42667             96.7   28.3   9.127778

# %% [markdown]
# ## 20-day exposure

# %%
df_deg_bins_20 <- df_deg_bins[Day_Min <=20]
sprintf("%i x %i dataframe", nrow(df_deg_bins_20), ncol(df_deg_bins_20))
head(df_deg_bins,2)
# Out:
# [1] "35416118 x 7 dataframe"
#   Measured_date_CDC cell_x cell_y Temp_bin  N_hours Temp Day_Min
# 1 42474             91.9   27.6   T0DayMin1 2       0    1
# 2 42667             96.7   28.3   T0DayMin1 2       0    1

# %%
result_20 <- df_deg_bins_20[, .(T_i20 = sum(N_hours * Temp / 24 / 20, na.rm = TRUE)), 
                          by = .(Measured_date_CDC, cell_x, cell_y)]
sprintf("%i x %i dataframe", nrow(result_20), ncol(result_20))
head(result_20,2)
# Out:
# [1] "173657 x 4 dataframe"
#   Measured_date_CDC cell_x cell_y T_i20
# 1 42474             91.9   27.6   4.510417
# 2 42667             96.7   28.3   8.314583

# %% [markdown]
# ## 10-day exposure

# %%
df_deg_bins_10 <- df_deg_bins[Day_Min <=10]
sprintf("%i x %i dataframe", nrow(df_deg_bins_10), ncol(df_deg_bins_10))
head(df_deg_bins_10,2)
# Out:
# [1] "17682220 x 7 dataframe"
#   Measured_date_CDC cell_x cell_y Temp_bin  N_hours Temp Day_Min
# 1 42474             91.9   27.6   T0DayMin1 2       0    1
# 2 42667             96.7   28.3   T0DayMin1 2       0    1

# %%
result_10 <- df_deg_bins_10[, .(T_i10 = sum(N_hours * Temp / 24 / 10, na.rm = TRUE)), 
                          by = .(Measured_date_CDC, cell_x, cell_y)]
sprintf("%i x %i dataframe", nrow(result_10), ncol(result_10))
head(result_10,2)
# Out:
# [1] "173657 x 4 dataframe"
#   Measured_date_CDC cell_x cell_y T_i10
# 1 42474             91.9   27.6   5.112500
# 2 42667             96.7   28.3   7.016667

# %% [markdown]
# ## MERGE

# %%
result <- data.frame(result_30) %>%
                left_join(result_20,by=c("Measured_date_CDC","cell_x","cell_y"))%>%
                left_join(result_10,by=c("Measured_date_CDC","cell_x","cell_y"))
sprintf("%i x %i dataframe", nrow(result), ncol(result))
head(result,2)
# Out:
# [1] "173657 x 6 dataframe"
#   Measured_date_CDC cell_x cell_y T_i30    T_i20    T_i10
# 1 42474             91.9   27.6   3.495833 4.510417 5.112500
# 2 42667             96.7   28.3   9.127778 8.314583 7.016667

# %%
data.frame(result) %>% 
        select(T_i30,T_i20,T_i10)%>%
        stargazer(nobs=TRUE, digits = 2,
                  summary.stat = c("n","mean", "sd","min","p25","median","p75","max"),
                  title = c("Summary statistics"),
                  type="text"
                     )
# Out:
# Summary statistics
# ======================================================================
# Statistic    N    Mean  St. Dev.  Min   Pctl(25) Median Pctl(75)  Max
# ----------------------------------------------------------------------
# T_i30     173,657 22.96   6.49   -14.62  18.72   24.27   27.61   37.43
# T_i20     173,657 23.12   6.46   -15.53  19.05   24.47   27.66   37.48
# T_i10     173,657 23.31   6.41   -16.78  19.41   24.55   27.74   38.16
# ----------------------------------------------------------------------

# %% [markdown]
# # Categorize temperature into bins

# %% [markdown]
# ### Air temperature thresholds

# %%
thresholds_T <- c(-17,17,21,23,25,27,29,31,33,40)

# %%
T_bins_labels <- c("<=17°C","(17,21]","(21,23]","(23,25]","(25,27]","(27,29]","(29,31]","(31,33]",">33°C")

# %%
result_bins <- result %>%
                    mutate(T_i30_bin = cut(T_i30, breaks = thresholds_T, 
                                           labels = T_bins_labels ,
                                           include.lowest = TRUE),
                           T_i20_bin = cut(T_i20, breaks = thresholds_T, 
                                           labels = T_bins_labels ,
                                           include.lowest = TRUE),
                           T_i10_bin = cut(T_i10, breaks = thresholds_T, 
                                           labels = T_bins_labels ,
                                           include.lowest = TRUE))
sprintf("%i x %i dataframe", nrow(result_bins), ncol(result_bins))
head(result_bins,2)
# Out:
# [1] "173657 x 9 dataframe"
#   Measured_date_CDC cell_x cell_y T_i30    T_i20    T_i10    T_i30_bin
# 1 42474             91.9   27.6   3.495833 4.510417 5.112500 <=17°C
# 2 42667             96.7   28.3   9.127778 8.314583 7.016667 <=17°C
#   T_i20_bin T_i10_bin
# 1 <=17°C    <=17°C
# 2 <=17°C    <=17°C

# %% [markdown]
# ## SAVE

# %%
fwrite(result_bins,"./output/df_T_cells_CDC_30_20_10.csv")
